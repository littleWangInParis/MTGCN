# %%
import pickle
import numpy

with open("./data/k_sets.pkl", "rb") as f:
    data = pickle.load(f)

print(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       1 import pickle
#       3 with open("./data/k_sets.pkl", "rb") as f:
# ----> 4     data = pickle.load(f)
#       6 print(data)
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# Out:
# <class 'int'>
